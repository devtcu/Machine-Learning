# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
 from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd #useful for data set loading
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc #fc is feature column

import tensorflow as tf

# %% [markdown]
# Let us bring in some data - speciically from the titanic. And then we can try to make some predictions.

# %%
# Load dataset.
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') # training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') # testing data - it wouldnt make sense to give the model the same data set as a test, so this is a fresh new one

y_train = dftrain.pop('survived') #just takes the survived coulmn into this variable
y_eval = dfeval.pop('survived')

# %%
dftrain.head()
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %%
print(dftrain.loc[0], y_train.loc[0])
# Out:
# sex                          male
# age                          22.0
# n_siblings_spouses              1
# parch                           0
# fare                         7.25
# class                       Third
# deck                      unknown
# embark_town           Southampton
# alone                           n
# Name: 0, dtype: object 0

# %%
dftrain.describe() #summary of the data
# Out:
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200

# %% [markdown]
# Now let us make a histogram

# %%
dftrain.age.hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# and then sex vs survival rate

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh').set_xlabel('% survive')
# Out:
# Text(0.5, 0, '% survive')

# %%
# Out:
# WARNING:tensorflow:From /var/folders/40/b39qh12x3dj80dkq4q34vz4h0000gn/T/ipykernel_27038/3788514006.py:8: categorical_column_with_vocabulary_list (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Keras preprocessing layers instead, either directly or via the `tf.keras.utils.FeatureSpace` utility. Each of `tf.feature_column.*` has a functional equivalent in `tf.keras.layers` for feature preprocessing when training a Keras model.
